# %% [markdown]
# <a href="https://colab.research.google.com/github/shane-SL/team_4/blob/main/nnverify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.models import load_model
model = load_model("/content/drive/MyDrive/Tebame_第四組_機車辨識/機車辨識模型檔/VGG16_allclass_rigorous_deepconv_run3.h5")

# %%
import glob
# GP125
gp = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/KYMCO_GP_125_裁/*")

# 活力 125 原始+ 裁
vivo = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/SYM_活力_125_裁/*")

# 勁戰六代 原始+ 裁
gryphus6 = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/YAMAHA_六代勁戰_125_裁/*")

# SYM JET SR  ...
SR = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/SYM_JET_SR_125_裁/*")

# SYM JET SL  ...
SL = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/SYM_JET_SL_125_裁/*")

# YAMAHA JOG  ...
JOG = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/YAMAHA_JOG_125_裁/*")

# YAMAHA BWS  ...
BWS = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/YAMAHA_BWS_125_裁/*")

# YAMAHA LIMI  ...
LIMI = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/YAMAHA_LIMI_125_已裁減/*")

# KYMCO LIKE
LIKE = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/KYMCO_LIKE_125_裁/*")

# DRG
DRG = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/SYM_DRG_裁/*") 

# FIDDLE
FIDDLE = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/SYM_FIDDLE_125_裁/*") 

# gogoro S2
S2 = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/GOGORO_S2_裁/*")

# gogoro S3
S3 = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/GOGORO_S3_裁/*")

# gogoro VIVA_MIX
VIVAMIX = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/GOGORO_VIVA_MIX_裁/*")

# 新名流125
xml125 = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/KYMCO_新名流125_裁/*")

# YAMAHA 勁豪
JH = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/YAMAHA_勁豪_125_裁/*")

# KRV
KRV = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/KYMCO_KRV_裁/*")

# KYMCO MANY
MANY = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/KYMCO_MANY_125_裁/*")

# YAMAHA FORCE
Force = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/YAMAHA_FORCE_裁/*")

# SYM 新迪爵
xdj = glob.glob("/content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集1116/SYM_新迪爵_125 _裁/*")

# %%
import pandas as pd
df = pd.DataFrame({
    "path": gp + vivo + gryphus6 + SR + SL + JOG + BWS + LIMI + LIKE + DRG + FIDDLE + S2 + S3 + VIVAMIX + xml125 + JH + KRV + MANY + Force +xdj,
    "ans": [0] * len(gp) + [1] * len(vivo) + [2] * len(gryphus6) + [3] * len(SR) + [4] * len(SL) + [5] * len(JOG) + [6] * len(BWS) + [7] * len(LIMI) + [8] * len(LIKE) + [9] * len(DRG) + [10] * len(FIDDLE) + [11] * len(S2) + [12] * len(S3) + [13] * len(VIVAMIX) + [14] * len(xml125) + [15] * len(JH) + [16] * len(KRV) + [17] * len(MANY) + [18] * len(Force) + [19] * len(xdj)
})
df
# Out:
#                                                   path  ans
# 0    /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...    0
# 1    /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...    0
# 2    /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...    0
# 3    /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...    0
# 4    /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...    0
# ..                                                 ...  ...
# 856  /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...   19
# 857  /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...   19
# 858  /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...   19
# 859  /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...   19
# 860  /content/drive/MyDrive/Tebame_第四組_機車辨識/測試測試集11...   19
#
# [861 rows x 2 columns]

# %%
import random
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
# import 匯入 當初預處理的方式
from tensorflow.keras.applications.vgg16 import preprocess_input

# %%
x = np.array(df["path"])
y = np.array(df["ans"])

# %%
def data_generator(x, y, batch_size=19):
  while True:
    idx = np.random.randint(0, len(x), size=batch_size)
    x_batch, y_batch = x[idx], y[idx]
    x_final = []
    for path in x_batch:
      img = Image.open(path).resize((224, 224)).convert("RGB")    #  開啟路徑圖檔並改大小、轉成RGB
      img_pre = preprocess_input(np.array(img))              # 轉成陣列再預處理
      x_final.append(img_pre)            
    x_final = np.array(x_final)
    y_batch = np.array(y_batch)
    yield (x_final, y_batch)
gen = data_generator(x, y)
x_gen, y_gen = gen.__next__()
print(x_gen.shape)
print(y_gen.shape)
print(x_gen)
print(y_gen)
# Out:
# (19, 224, 224, 3)
# (19,)
# [[[[ 83.061       69.221       66.32      ]
#    [126.061      108.221      101.32      ]
#    [144.061      124.221      114.32      ]
#    ...
#    [ 89.061       77.221       88.32      ]
#    [ 79.061       64.221       72.32      ]
#    [ 66.061       49.221       56.32      ]]
#
#   [[ 81.061       67.221       65.32      ]
#    [120.061      102.221       95.32      ]
#    [146.061      126.221      116.32      ]
#    ...
#    [140.061      136.22101    131.32      ]
#    [137.061      134.22101    130.32      ]
#    [135.061      132.22101    129.32      ]]
#
#   [[ 79.061       68.221       66.32      ]
#    [111.061       91.221       86.32      ]
#    [146.061      124.221      115.32      ]
#    ...
#    [128.061      115.221      114.32      ]
#    [130.061      117.221      114.32      ]
#    [131.061      119.221      115.32      ]]
#
#   ...
#
#   [[ 42.060997    13.221001     0.3199997 ]
#    [ 46.060997    16.221        4.3199997 ]
# ...

# %%
test_generator = data_generator(x,y)

# %%
model.evaluate_generator(test_generator, steps=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.
